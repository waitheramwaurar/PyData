# %% [markdown]
# ## The Data Analysis Pipeline
#
# 1. Clean the data
# - Handling missingness
# - Handling outliers
# - Handlind duplicate
# - Addressing data type mismatches
#
# 2. Univariate analysis - gather insight on one variable
# 3. Bivariate analysis - identify relationships
# 4. Multivariate analysis - relationship between multiple variables

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    ID        date  meals_served  kitchen_staff  temperature_C  \
# 0   0  19/12/2022           196             13      27.887273
# 1   1  21/11/2023           244             15      10.317872
# 2   4  01/02/2022           148             16      27.714300
# 3   5  19/03/2023           157             19      19.173902
# 4   6  18/07/2022           297             10      26.375233
#
#    humidity_percent  day_of_week  special_event  past_waste_kg  \
# 0         45.362854            0              0       7.740587
# 1         64.430475            1              0      42.311779
# 2         69.046113            1              0      41.184305
# 3         46.292823            6              0      41.543492
# 4         79.741064            0              0      26.525097
#
#   staff_experience waste_category           food_waste_kg
# 0     intermediate          dairy  28.946465336432905  kg
# 1              NaN           MeAt   51.54905281454645  kg
# 2         Beginner           MeAt  53.008322732556536  kg
# 3         Beginner           MeAt   48.62152711280995  kg
# 4     Intermediate           MEAT   44.15698435866615  kg

# %%
train.shape
# Out:
# (911, 12)

# %%
train.dtypes
# Out:
# ID                    int64
# date                 object
# meals_served          int64
# kitchen_staff         int64
# temperature_C       float64
# humidity_percent    float64
# day_of_week           int64
# special_event         int64
# past_waste_kg       float64
# staff_experience     object
# waste_category       object
# food_waste_kg        object
# dtype: object

# %%
train['date'] = pd.to_datetime(train['date'], format='mixed')
train['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
train['day'] = train['date'].dt.dayofweek
train.head()
# Out:
#    ID       date  meals_served  kitchen_staff  temperature_C  \
# 0   0 2022-12-19           196             13      27.887273
# 1   1 2023-11-21           244             15      10.317872
# 2   4 2022-01-02           148             16      27.714300
# 3   5 2023-03-19           157             19      19.173902
# 4   6 2022-07-18           297             10      26.375233
#
#    humidity_percent  day_of_week  special_event  past_waste_kg  \
# 0         45.362854            0              0       7.740587
# 1         64.430475            1              0      42.311779
# 2         69.046113            1              0      41.184305
# 3         46.292823            6              0      41.543492
# 4         79.741064            0              0      26.525097
#
#   staff_experience waste_category           food_waste_kg  day
# 0     intermediate          dairy  28.946465336432905  kg    0
# 1              NaN           MeAt   51.54905281454645  kg    1
# 2         Beginner           MeAt  53.008322732556536  kg    6
# 3         Beginner           MeAt   48.62152711280995  kg    6
# 4     Intermediate           MEAT   44.15698435866615  kg    0

# %%
# day_of_week column is wrong, so we drop

train.drop('day_of_week', axis=1, inplace=True)
train.head()
# Out:
#    ID       date  meals_served  kitchen_staff  temperature_C  \
# 0   0 2022-12-19           196             13      27.887273
# 1   1 2023-11-21           244             15      10.317872
# 2   4 2022-01-02           148             16      27.714300
# 3   5 2023-03-19           157             19      19.173902
# 4   6 2022-07-18           297             10      26.375233
#
#    humidity_percent  special_event  past_waste_kg staff_experience  \
# 0         45.362854              0       7.740587     intermediate
# 1         64.430475              0      42.311779              NaN
# 2         69.046113              0      41.184305         Beginner
# 3         46.292823              0      41.543492         Beginner
# 4         79.741064              0      26.525097     Intermediate
#
#   waste_category           food_waste_kg  day
# 0          dairy  28.946465336432905  kg    0
# 1           MeAt   51.54905281454645  kg    1
# 2           MeAt  53.008322732556536  kg    6
# 3           MeAt   48.62152711280995  kg    6
# 4           MEAT   44.15698435866615  kg    0

# %%
# So that we can perform calculations on the food_waste_kg column, we need to convert to float
train['food_waste_kg'] = train['food_waste_kg'].astype(str).str.replace('kg', '').astype(float)
# This is converting the whole thing to string explicitly, then remove the 'kg' and then convert
# float
train['food_waste_kg'].dtype
# Out:
# dtype('float64')

# %%
# Change everything in the staff experience to lowercase
train['staff_experience'] = train['staff_experience'].str.lower()
train['waste_category'] = train['waste_category'].str.lower()
train.head()
# Out:
#    ID       date  meals_served  kitchen_staff  temperature_C  \
# 0   0 2022-12-19           196             13      27.887273
# 1   1 2023-11-21           244             15      10.317872
# 2   4 2022-01-02           148             16      27.714300
# 3   5 2023-03-19           157             19      19.173902
# 4   6 2022-07-18           297             10      26.375233
#
#    humidity_percent  special_event  past_waste_kg staff_experience  \
# 0         45.362854              0       7.740587     intermediate
# 1         64.430475              0      42.311779              NaN
# 2         69.046113              0      41.184305         beginner
# 3         46.292823              0      41.543492         beginner
# 4         79.741064              0      26.525097     intermediate
#
#   waste_category  food_waste_kg  day
# 0          dairy      28.946465    0
# 1           meat      51.549053    1
# 2           meat      53.008323    6
# 3           meat      48.621527    6
# 4           meat      44.156984    0

# %%
train.dtypes
# Out:
# ID                           int64
# date                datetime64[ns]
# meals_served                 int64
# kitchen_staff                int64
# temperature_C              float64
# humidity_percent           float64
# special_event                int64
# past_waste_kg              float64
# staff_experience            object
# waste_category              object
# food_waste_kg              float64
# day                          int32
# dtype: object

# %% [markdown]
# ### Handling missingness
# Types of missingness
# 1. MCAR - missing completely at random: missingness does not have anything to do with the data itself, does not introduce bias, it just misses. You can choose to drop or impute that record.
# 2. MAR - missing at random: the fact that this data is missing has nothing to do with the data but with other variables; missingness can be explained by looking at other columns.
# 3. MNAR - missing not at random: the fact that the data is missing is because of the data itself. Requires quite advanced imputations to prevent bias.

# %%
# Looking for missingness
# 1. Identify missingness - using .info() or missingno library to visualize the missingness
# Visualizing missingness can help see why the data is missing
# 2. What is the extent of missingness
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911 entries, 0 to 910
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                911 non-null    int64
#  1   date              911 non-null    datetime64[ns]
#  2   meals_served      911 non-null    int64
#  3   kitchen_staff     911 non-null    int64
#  4   temperature_C     911 non-null    float64
#  5   humidity_percent  911 non-null    float64
#  6   special_event     911 non-null    int64
#  7   past_waste_kg     911 non-null    float64
#  8   staff_experience  747 non-null    object
#  9   waste_category    911 non-null    object
#  10  food_waste_kg     911 non-null    float64
#  11  day               911 non-null    int32
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(4), object(2)
# memory usage: 82.0+ KB

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\rmwaura\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\rmwaura\anaconda3\lib\site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\rmwaura\anaconda3\lib\site-packages (from missingno) (3.8.4)
# Requirement already satisfied: scipy in c:\users\rmwaura\anaconda3\lib\site-packages (from missingno) (1.13.1)
# Requirement already satisfied: seaborn in c:\users\rmwaura\anaconda3\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rmwaura\anaconda3\lib\site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rmwaura\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rmwaura\anaconda3\lib\site-packages (from matplotlib->missingno) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rmwaura\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rmwaura\appdata\roaming\python\python312\site-packages (from matplotlib->missingno) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\rmwaura\anaconda3\lib\site-packages (from matplotlib->missingno) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rmwaura\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rmwaura\anaconda3\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\rmwaura\anaconda3\lib\site-packages (from seaborn->missingno) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rmwaura\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rmwaura\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\rmwaura\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import missingno as mn

# %%
mn.matrix(train)
# Out:
# <Axes: >

# %%
# Another way of checking for missing values
train.isnull()
# Out:
#         ID   date  meals_served  kitchen_staff  temperature_C  \
# 0    False  False         False          False          False
# 1    False  False         False          False          False
# 2    False  False         False          False          False
# 3    False  False         False          False          False
# 4    False  False         False          False          False
# ..     ...    ...           ...            ...            ...
# 906  False  False         False          False          False
# 907  False  False         False          False          False
# 908  False  False         False          False          False
# 909  False  False         False          False          False
# 910  False  False         False          False          False
#
#      humidity_percent  special_event  past_waste_kg  staff_experience  \
# 0               False          False          False             False
# 1               False          False          False              True
# 2               False          False          False             False
# 3               False          False          False             False
# 4               False          False          False             False
# ..                ...            ...            ...               ...
# 906             False          False          False             False
# 907             False          False          False             False
# 908             False          False          False             False
# 909             False          False          False             False
# 910             False          False          False             False
#
#      waste_category  food_waste_kg    day
# 0             False          False  False
# 1             False          False  False
# 2             False          False  False
# 3             False          False  False
# 4             False          False  False
# ..              ...            ...    ...
# 906           False          False  False
# 907           False          False  False
# 908           False          False  False
# 909           False          False  False
# 910           False          False  False
#
# [911 rows x 12 columns]

# %%
train.isnull().sum() #.sum() counts the number of Trues in each column
# Out:
# ID                    0
# date                  0
# meals_served          0
# kitchen_staff         0
# temperature_C         0
# humidity_percent      0
# special_event         0
# past_waste_kg         0
# staff_experience    164
# waste_category        0
# food_waste_kg         0
# day                   0
# dtype: int64

# %%
# Quantify the missingness in order to know what to do with the missing values
# e.g if you're missing 50% of the data, you can drop the columns

total_values = train.count() # counts all values, whether null or not
total_missing=train.isnull().sum()
percent_missing = (total_missing/total_values)*100
percent_missing
# Out:
# ID                   0.000000
# date                 0.000000
# meals_served         0.000000
# kitchen_staff        0.000000
# temperature_C        0.000000
# humidity_percent     0.000000
# special_event        0.000000
# past_waste_kg        0.000000
# staff_experience    21.954485
# waste_category       0.000000
# food_waste_kg        0.000000
# day                  0.000000
# dtype: float64

# %%
# Creating a mask to filter all the null value to try and see why that column has missingness
null_mask = train.isnull().any(axis=1)
df_nulls=train[null_mask]
df_nulls
# Since there is no clear pattern for missingness, we can impute
# Out:
#        ID       date  meals_served  kitchen_staff  temperature_C  \
# 1       1 2023-11-21           244             15      10.317872
# 14     17 2023-04-29           378             12      12.323229
# 19     22 2024-09-09           253             17      12.768711
# 31     34 2022-12-04           114              8      24.756598
# 38     41 2024-01-01           272             11      16.947552
# ..    ...        ...           ...            ...            ...
# 882  1019 2022-01-09           302             18      25.138454
# 886  1023 2022-01-26           260             10      30.168112
# 888  1025 2024-08-15           449              6      29.964832
# 894  1031 2024-06-05           153             12      29.296443
# 903  1041 2024-09-02           415             11      28.085119
#
#      humidity_percent  special_event  past_waste_kg staff_experience  \
# 1           64.430475              0      42.311779              NaN
# 14          68.060384              0      41.146021              NaN
# 19          42.373044              0       6.584683              NaN
# 31          38.251426              0      25.343897              NaN
# 38          32.858475              0      30.910364              NaN
# ..                ...            ...            ...              ...
# 882         65.759331              1      12.473368              NaN
# 886         75.554924              0      21.410180              NaN
# 888         84.691278              0      18.051981              NaN
# 894         55.832413              0      28.313472              NaN
# 903         75.748973              0       8.919918              NaN
#
#     waste_category  food_waste_kg  day
# 1             meat      51.549053    1
# 14            meat      51.058018    5
# 19           dairy      18.665798    0
# 31            meat      23.016292    6
# 38            meat      39.502640    0
# ..             ...            ...  ...
# 882           meat      49.759978    6
# 886     vegetables      29.899846    2
# 888     vegetables      37.536338    3
# 894         grains      38.313965    2
# 903           meat      41.321267    0
#
# [164 rows x 12 columns]

# %% [markdown]
# ### Imputation
#
# Three methods:
# 1. Median - best for numerical values to avoid bias
# 2. Mean
# 3. Mode

# %%
train['staff_experience'].fillna(train['staff_experience'].mode()[0], inplace=True)

# We have indexing for mode because we can have multiple modes
# so we are telling it to pick the first mode
train.isnull().sum()
# Out:
# C:\Users\RMwaura\AppData\Local\Temp\ipykernel_20768\2504681774.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['staff_experience'].fillna(train['staff_experience'].mode()[0], inplace=True)
# ID                  0
# date                0
# meals_served        0
# kitchen_staff       0
# temperature_C       0
# humidity_percent    0
# special_event       0
# past_waste_kg       0
# staff_experience    0
# waste_category      0
# food_waste_kg       0
# day                 0
# dtype: int64

# %% [markdown]
# ### Handling Outliers
#
# This is to ensure there is no bias, checking errors and correctness.

# %%
# 1. Draw a boxplot - and only plot the numerical columns

numeric_cols = train.select_dtypes(include=np.number).columns.tolist()
numeric_cols
# Out:
# ['ID',
#  'meals_served',
#  'kitchen_staff',
#  'temperature_C',
#  'humidity_percent',
#  'special_event',
#  'past_waste_kg',
#  'food_waste_kg',
#  'day']

# %%
cols = ['meals_served','kitchen_staff','temperature_C','humidity_percent','special_event','past_waste_kg','food_waste_kg']
num_df=train[cols]

fig = plt.figure(figsize=(15,30))

for i in range(len(cols)):
 ax= fig.add_subplot(9, 5, i+1)
 sns.boxplot(x=num_df.iloc[:, i],ax=ax)
    
plt.tight_layout()
plt.show()

# %%
Q3 = np.quantile(train['temperature_C'], 0.75)
Q1 = np.quantile(train['temperature_C'], 0.25)

IQR = Q3 - Q1
lower_range = Q1-(1.5*IQR)
upper_range = Q3+ (1.5*IQR)

# %%
clean_df = train[(train['temperature_C'] >= lower_range) & (train['temperature_C'] <= upper_range)]
clean_df.shape
# Out:
# (889, 12)

# %%
# Write another condition to give us a df of outliers

outlier_df = train[~((train['temperature_C'] >= lower_range) & (train['temperature_C'] <= upper_range))]
outlier_df
# Out:
#       ID       date  meals_served  kitchen_staff  temperature_C  \
# 12    15 2022-01-25           376             19     -10.372207
# 102  115 2024-02-24           134              6     -10.000000
# 238  279 2023-06-03           453              5     -10.000000
# 290  337 2022-08-28           259              9      60.000000
# 300  350 2023-07-03           421             18      60.000000
# 345  401 2024-01-02           472              7     -10.000000
# 384  450 2022-03-15           359             10     -10.000000
# 396  464 2023-02-27           420              5      60.000000
# 404  474 2023-04-14           469             12      60.000000
# 407  477 2022-01-25           376             19     -10.000000
# 445  521 2023-01-29           459             16     -10.000000
# 463  539 2023-07-30           341              9     -10.000000
# 492  571 2022-04-04           152             14     -10.000000
# 537  621 2022-12-20           383             14      60.000000
# 560  645 2023-09-18           286             15      60.000000
# 641  747 2024-04-02           447             12      60.000000
# 701  815 2022-09-25           247             19     -10.000000
# 710  825 2023-09-01           379             15     -10.000000
# 766  887 2023-06-04           471              6      60.000000
# 768  889 2024-07-05           335             15     -10.000000
# 804  933 2022-05-19           356             13      60.000000
# 852  987 2024-07-20           150             14     -10.000000
#
#      humidity_percent  special_event  past_waste_kg staff_experience  \
# 12          54.498381              0      36.259420           expert
# 102         37.796482              0      49.359571         beginner
# 238         57.790363              1      48.434434     intermediate
# 290         52.734617              0      49.281418         beginner
# 300         44.079207              0      24.268277     intermediate
# 345         79.081605              0      27.590369           expert
# 384         82.634367              0      47.370958     intermediate
# 396         73.187487              0      21.827621         beginner
# 404         32.537505              0      35.121064     intermediate
# 407         54.498381              0      36.259420           expert
# 445         64.622440              0      30.083223         beginner
# 463         44.349527              0      36.750322           expert
# 492         82.113090              0       8.452527     intermediate
# 537         31.847403              0       6.391890           expert
# 560         53.511498              0      21.347276           expert
# 641         37.521389              0       7.453037     intermediate
# 701         52.223819              1      12.627684         beginner
# 710         30.139053              0      22.312966         beginner
# 766         64.308550              1      44.209186           expert
# 768         82.679070              0      38.660723         beginner
# 804         80.635477              0      44.147202     intermediate
# 852         86.379091              1      23.103817     intermediate
#
#     waste_category  food_waste_kg  day
# 12            meat      50.568699    1
# 102           meat      36.163483    5
# 238     vegetables      71.752271    5
# 290           meat      44.955417    6
# 300           meat      33.139494    0
# 345     vegetables      46.991245    1
# 384           meat      70.472339    1
# 396           meat      40.893641    0
# 404           meat      67.151136    4
# 407           meat      50.568699    1
# 445           meat      60.690374    6
# 463           meat      47.533061    6
# 492         grains      30.175709    0
# 537          dairy      35.352474    1
# 560          dairy      34.982513    0
# 641           meat      37.225888    1
# 701          dairy      42.581728    6
# 710          dairy      45.178594    4
# 766         grains      64.037547    6
# 768           meat      52.082864    4
# 804           meat      50.385559    3
# 852     vegetables      47.439001    5

# %%
outlier_df.shape
# Out:
# (22, 12)

# %% [markdown]
# ### Line Plots
#
# - Used when you want to visual trends and patterns with temporal components
# - Used to communicate how a component has been over time

# %%
plt.figure(figsize=(15,6)) # creating the plot area

sns.lineplot(x='date', y='food_waste_kg', data=clean_df) 

plt.show()

# %%
plt.figure(figsize=(15,6)) # creating the plot area

sns.lineplot(x='date', y='food_waste_kg', data=clean_df, hue='staff_experience') 
# hue kind of groups the different line plots by what has been specified
plt.show()

# %%
# Resampling the data in quarters
per_quarter_df = clean_df.set_index('date').resample('Q').mean(numeric_only=True).reset_index()
per_quarter_df.head()
# Out:
# C:\Users\RMwaura\AppData\Local\Temp\ipykernel_20768\495772871.py:2: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   per_quarter_df = clean_df.set_index('date').resample('Q').mean(numeric_only=True).reset_index()
#         date          ID  meals_served  kitchen_staff  temperature_C  \
# 0 2022-03-31  495.333333    471.038095      11.971429      21.909688
# 1 2022-06-30  513.953488    306.674419      11.197674      23.088494
# 2 2022-09-30  527.920000    435.453333      11.880000      22.592935
# 3 2022-12-31  482.929412    337.800000      12.576471      22.234766
# 4 2023-03-31  523.901408    310.042254      11.309859      21.128856
#
#    humidity_percent  special_event  past_waste_kg  food_waste_kg       day
# 0         62.254422       0.085714      28.473953      47.940149  3.076190
# 1         61.453604       0.069767      25.867882      42.013884  3.104651
# 2         59.055693       0.026667      26.498908      46.318560  2.960000
# 3         59.492843       0.105882      25.091305      43.274925  3.058824
# 4         58.639050       0.126761      28.215497      41.388379  3.014085

# %%
plt.figure(figsize=(15,6))


sns.lineplot(x='date', y='food_waste_kg', data=per_quarter_df, linewidth=3, )

plt.title('Food waste in kg per quarter')

plt.show()

# %% [markdown]
# ### Scatter plot
#
# - Used to identify relationship between two numerical variables

# %%
plt.figure(figsize=(15,6))


sns.scatterplot(x='meals_served', y='food_waste_kg', data=clean_df)

# plt.title('Food waste in kg per quarter')

plt.show()

# %%
plt.figure(figsize=(15,6))


sns.regplot(x='meals_served', y='food_waste_kg', data=clean_df)

# plt.title('Food waste in kg per quarter')

plt.show()

# %%
plt.figure(figsize=(15,6))


sns.scatterplot(x='meals_served', y='food_waste_kg', data=clean_df, hue='staff_experience')

# plt.title('Food waste in kg per quarter')

plt.show()

# %%
plt.figure(figsize=(15,6))


sns.scatterplot(x='meals_served', y='food_waste_kg', data=clean_df, hue='waste_category', style='waste_category')

# plt.title('Food waste in kg per quarter')

plt.show()

# %% [markdown]
# ### Histograms
#
# - Used when you want to visualize the distribution of your data

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=clean_df, x='food_waste_kg', bins=20, kde=True)
# kernel density estimate

# Data distribution helps to see the skewness
plt.grid(True)
plt.show()

# Identifying outliers - although bosplot is best
# determining what to do with missing values - depending on the distribution (if normal - you can impute with mean else use mode)

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=clean_df, x='food_waste_kg', bins=20, hue='staff_experience')
# kernel density estimate

# Data distribution helps to see the skewness
plt.grid(True)
plt.show()

# %%
# kde plot

# %% [markdown]
# ### Correlation matrix and heatmap
#
# - Used for multivariate analysis
# - Correlation matrix: done with numerical columns

# %%
corr = clean_df[numeric_cols].corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Heatmap of Selected Columns')
plt.show()
